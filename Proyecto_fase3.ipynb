# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoReyes27/A01284917_Proyecto_Pensamiento-computacional-para-ingenieria-Gpo-52-/blob/main/Proyecto_fase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre Entrega: Evidencia 1: Entrega Etapa 3 del Proyecto Integrador
#
# Nombre: Rodrigo Reyes
#
# Matricula: A01284917
#
# Fecha: 16 de octubre de 2021
#
# Materia: Pensamiento computacional para ingeniería
#
# Profesor: Ing. Germán Domínguez
#
# Link: https://colab.research.google.com/drive/1SuY5Nay_NDYp2wk8ScPfcUe8z7jegM3b?usp=sharing
#
# Link GitHub: https://github.com/RodrigoReyes27/A01284917_Proyecto_Pensamiento-computacional-para-ingenieria-Gpo-52-.git

# %% [markdown]
# ## Descripción del problema, solución y funcionalidad

# %% [markdown]
# En este proyecto el problema que se planea resolver es las bajas calificaciones de los alumnos mexicanos de 15 años en la prueba PISA, la cual es un examen en el que se evalúan las áreas de matemáticas, lectura y ciencias. Debido a esto, el programa esta enfocado para que los alumnos puedan mejorar sus habilidades al responder preguntas de las tres diferentes áreas, ya sea un área en especifico o las tres al mismo tiempo.
# El programa que le dará solución a este problema tendrá un total de 8 funciones, las cuales son main, menú, registrar pregunta, actualizar pregunta, estudiar área, presentar quiz, reportar calificaciones, salir. La funcionalidad de las funciones será tal que, la función de Menú desplegará las diferentes opciones que se pueden hacer con el programa. La función Main tendrá un ciclo WHILE, donde se llamará a la función Menú para así mostrar el menú, y también la función Main servirá para redirigir al usuario a la opción que haya elegido del menu. Y cuando el usuario seleccione la opción de salir el ciclo se terminará y también el programa. El modo en el que se planea almacenar las preguntas es dentro de una Lista, llamada base_datos_preguntas, la cual será una variable global. Para añadir preguntas a la base de datos se usará la función Registrar_pregunta, donde el usuario podrá añadir el área de la pregunta, el texto de la pregunta, el texto de las opciones a,b,c,d y también la letra de la respuesta. Lo anterior se guardará en una lista llamada pregunta y después la pregunta a la lista base_datos_preguntas con el método append. De este modo la lista base_datos_preguntas será una lista 2d, la cual quedará tal que base_datos_preguntas[número de pregunta][diferentes datos de la pregunta]. En el caso de la función actualizar pregunta, lo que se hará es mostrar un menú con las tres áreas de preguntas, después el usuario seleccionara una de las áreas y el programa va a mostrar enumeradas todas las preguntas existentes en esa área, y el usuario ingresara el número de pregunta que desee actualizar. Después de esto se le proporcionara al usuario inputs para ingresar la nueva información para la pregunta. Para el caso de la función estudiar área, lo que se hará es mostrar un menú con 4 opciones, tres para las áreas de preguntas y otra para todas las áreas. Después el usuario seleccionara una de estas opciones y el programa va a mostrarle preguntas aleatorias del área seleccionada, sus posibles respuestas y al final un input para que el usuario ingrese su respuesta. Lo que hará la función presentar quiz es preguntar al usuario la cantidad de preguntas que quiere responder en el quiz, después el programa usara un ciclo FOR para ejecutarse la cantidad de veces que el usuario ingreso, el modo en que se seleccionaran preguntas es eligiendo números aleatorios entre 0 y la longitud de la lista base_datos_preguntas – 1. Y para evitar que se repitan preguntas lo que se planea hacer es crear una lista, donde se vayan registrando el numero de pregunta que ya ha sido mostrado, y al momento de mostrar nuevas preguntas, indicarle al programa que muestre una pregunta solo si el numero creado aleatoriamente no esta dentro de la lista, donde se están registrando las preguntas que ya fueron mostradas. La función reportar calificaciones mostrara los resultados en los quizzes realizados. Y por último la función salir mostrara un mensaje de despedida al usuario.

# %% [markdown]
# ## Caso de prueba para funcion registrar_pregunta

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 1
#
# Salida:
#
# Complete los siguientes datos para la nueva pregunta
#
# Opciones para area: lectura, matematicas, ciencias
#
# Area:
#
# Entrada: matemáticas
#
# Salida: Pregunta
#
# Entrada: 6 * 6
#
# Salida: Opción A
#
# Entrada: 18
#
# Salida: Opción B
#
# Entrada: 24
#
# Salida: Opción C
#
# Entrada: 30
#
# Salida: Opción D
#
# Entrada: 36
#
# Salida: Respuesta
#
# Entrada: d
#
# Salida:
#
# Respuesta registrada correctamente con los siguientes datos:
#
# Id: 1
#
# Area: matematicas
#
# Pregunta: 6 * 6
#
# Opcion A: 18
#
# Opcion B: 24
#
# Opcion C: 30
#
# Opcion D: 36
#
# Respuesta: D

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 1
#
# Salida:
#
# Complete los siguientes datos para la nueva pregunta
#
# Opciones para area: lectura, matematicas, ciencias
#
# Area:
#
# Entrada: ciencias
#
# Salida: Pregunta
#
# Entrada: Seleccione el halogeno
#
# Salida: Opción A
#
# Entrada: Pb
#
# Salida: Opción B
#
# Entrada: F
#
# Salida: Opción C
#
# Entrada: C
#
# Salida: Opción D
#
# Entrada: Mg
#
# Salida: Respuesta
#
# Entrada: b
#
# Salida:
#
# Respuesta registrada correctamente con los siguientes datos:
#
# Id: 2
#
# Area: ciencias
#
# Pregunta: Seleccione el halogeno
#
# Opcion A: Pb
#
# Opcion B: F
#
# Opcion C: C
#
# Opcion D: Mg
#
# Respuesta: B

# %% [markdown]
# ## Casos de prueba para funcion Actualizar pregunta

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio:
#
# Entrada 2
#
# Salida:
#
# Sección para actualizar preguntas
#
# Selecciona una de las siguientes opciones para actualizar:
#
#
# Id: 1 Pregunta: 1+1
#
# Id: 2 Pregunta: 2+2
#
# Id: 3 Pregunta: fuente de energia de la celula
#
# Id: 4 Pregunta: elige el halogeno
#
# Ingrese el id de la pregunta que desee actualizar:
#
# Entrada: 1
#
# Salida:
#
# Datos pregunta a actualizar:
#
# Si desea actualizar la pregunta, escriba los nuevos datos, sino solo de enter
#
# Area: matemáticas
#
# Entrada:
#
# Salida: Pregunta: 1 + 1
#
# Entrada:
#
# Salida: Opción A: 1
#
# Entrada:
#
# Salida: Opción B: 2
#
# Entrada:
#
# Salida: Opción C: 3
#
# Entrada:
#
# Salida: Opción D: 4
#
# Entrada:
#
# Salida: Respuesta C
#
# Entrada: B
#
# Salida:
#
# Los nuevos datos de la pregunta id 1 son:
#
# Area: matematicas
#
# Pregunta: 1+1
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Respuesta: B
#
# Esta seguro de querer actualizar esta pregunta? y/n
#
# Entrada: p
#
# Salida: Ingrese una opcion existente
#
# Esta seguro de querer actualizar esta pregunta? y/n
#
# Entrada: y
#
# Salida: Pregunta actualizada exitosamente

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 2
#
# Salida:
#
# Sección para actualizar preguntas
#
# Selecciona una de las siguientes opciones para actualizar:
#
#
#
# Id: 1 Pregunta: 1+1
#
# Id: 2 Pregunta: 2+2
#
# Id: 3 Pregunta: fuente de energia de la celula
#
# Id: 4 Pregunta: elige el halogeno
#
# Ingrese el id de la pregunta que desee actualizar:
#
# Entrada: 5
#
# Salida: No existe ninguna pregunta con ese id

# %% [markdown]
# ## Casos de prueba para funcion estudiar_area

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 3
#
# Salida:
#
# Estudiar area
#
# ----------------------------------------
# Ingrese el número del area que desee estudiar:
#
# 1. Lectura
# 2. Matemáticas
# 3. Ciencias
#
# Número de área:
#
# Entrada: 1
#
# Salida: Escriba el número de preguntas que quiere estudiar de esta area:
#
# Entrada: 2
#
# Salida:
#
# Area lectura
#
# Lo sentimos pero no tenemos esa cantidad de preguntas para esta area, por lo
# que se usaran el maximo que tenemos: 1
#
# Numero 1
#
# Pregunta: Algo le ocurrió al personaje de la historia la noche anterior. ¿Qué
# fue lo que le pasó?
#
# Opcion A: El mal tiempo había estropeado la moto.
#
# Opcion B: El mal tiempo había impedido salir al personaje.
#
# Opcion C: El personaje había comprado una moto nueva.
#
# Opcion D: El personaje había tenido un accidente de moto
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Incorrecto!!
#
# Practica Finalizada
#
# Preguntas Correctas: 0 de 1

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 3
#
# Salida:
#
# Estudiar area
#
# ----------------------------------------
#
# Ingrese el número del area que desee estudiar:
# 1. Lectura
# 2. Matemáticas
# 3. Ciencias
#
# Número de área:
#
# Entrada: 2
#
# Salida: Escriba el número de preguntas que quiere estudiar de esta area:
#
# Entrada: 1
#
# Salida:
#
# Opcion matematicas
#
# Numero 1
#
# Pregunta: 2 * 2
#
# Opcion A: 4
#
# Opcion B: 5
#
# Opcion C: 6
#
# Opcion D: 7
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Correcto!!
#
# Practica Finalizada
#
# Preguntas Correctas: 1 de 1

# %% [markdown]
# ## Casos de prueba para funcion presentar_quiz

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 4
#
# Salida:
#
# Presentar quiz
#
# Para este quiz tendra 20 minutos, despues de eso aunque ingrese la repuesta,
# esta no se guardara
#
#
# Numero 1
#
# Pregunta: fuente de energia de la celula
#
# Opcion A: mitocondria
#
# Opcion B: nucleo
#
# Opcion C: nucleolus
#
# Opcion D: ninguna
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Correcto!!
#
#
#
# Numero 2
#
# Pregunta: 2 * 2
#
# Opcion A: 4
#
# Opcion B: 5
#
# Opcion C: 6
#
# Opcion D: 7
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Correcto!!
#
#
#
# Numero 3
#
# Pregunta: 2+2
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Incorrecto!!
#
#
#
# Numero 4
#
# Pregunta: 3+1
#
# Opcion A: 4
#
# Opcion B: 5
#
# Opcion C: 6
#
# Opcion D: 7
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Correcto!!
#
#
#
# Numero 5
#
# Pregunta: Algo le ocurrió al personaje de la historia la noche anterior. ¿Qué
# fue lo que le pasó?
#
# Opcion A: El mal tiempo había estropeado la moto.
#
# Opcion B: El mal tiempo había impedido salir al personaje.
#
# Opcion C: El personaje había comprado una moto nueva.
#
# Opcion D: El personaje había tenido un accidente de moto
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Incorrecto!!
#
#
#
# Numero 6
#
# Pregunta: 2+1
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
#
#
# Incorrecto!!
#
#
#
# Numero 7
#
# Pregunta: elige el halogeno
#
# Opcion A: Pb
#
# Opcion B: F
#
# Opcion C: C
#
# Opcion D: Mg
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Incorrecto!!
#
#
#
# Numero 8
#
# Pregunta: 4+1
#
# Opcion A: 4
#
# Opcion B: 5
#
# Opcion C: 6
#
# Opcion D: 7
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Incorrecto!!
#
#
#
# Numero 9
#
# Pregunta: 5+1
#
# Opcion A: 4
#
# Opcion B: 5
#
# Opcion C: 6
#
# Opcion D: 7
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Incorrecto!!
#
#
#
# Numero 10
#
# Pregunta: 1+1
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Ingrese la letra de la opción de la respuesta:
#
# Entrada: a
#
# Salida:
#
# Incorrecto!!
#
#
#
# Examen Finalizado
#
# Preguntas Correctas: 3 de 10

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 4
#
# Salida:
#
# Presentar quiz
#
# Para este quiz tendra 20 minutos, despues de eso aunque ingrese la repuesta,
# esta no se guardara
#
#
# Numero 1
#
# Pregunta: 1+1
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Entrada: b
#
# Salida:
#
# Correcto!!
#
#
# Numero 2
#
# Pregunta: 2+2
#
# Opcion A: 1
#
# Opcion B: 2
#
# Opcion C: 3
#
# Opcion D: 4
#
# Entrada: d
#
# Salida:
#
# Correcto!!
#
#
#
# Esta respuesta no fue guardada, porque se excedio de tiempo
#
# Examen Finalizado
#
# Preguntas Correctas: 1 de 10

# %% [markdown]
# ## Casos de prueba para funcion mostrar_calificaciones

# %% [markdown]
# ### Caso 1

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 5
#
# Salida:
#
#
# Reportar calificaciones
#
#
# Total de usuarios: 2
#
# Promedio de calificaciones: 41
#
# Preguntas correctas: 5
#
# Preguntas incorrectas: 7

# %% [markdown]
# ### Caso 2

# %% [markdown]
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
#
# Ingrese el número de la opcion que eligio:
#
# Entrada 5
#
# Salida:
#
# Reportar calificaciones
#
# No se pueden mostrar datos de calificaciones, porque aun no hay datos

# %% [markdown]
# ## Reflexion

# %% [markdown]
# Yo creo que aprendí varias cosas con este proyecto. Como, por ejemplo, la importancia y la utilidad de las listas 2D o matrices, ya que en este proyecto las use mucho para poder guardar y mostrar las preguntas que utilizaba mi programa. También me ayudo a aprender a como trabajar con archivos de texto, como forma para guardar información y que no se borre una vez cerrado el programa. Igualmente me ayudo a comprender la utilidad de crear funciones y también de darles parámetros, ya que estas hacen que no tenga que escribir el mismo código muchas veces para hacer cosas similares, y también para no tener que estar estableciendo valores a variables a cada rato. La ultima cosas en la que me ayudo el proyecto es a poner en práctica lo que aprendí en cuanto a condicionales (if, elif, else) y ciclos (for, while).
# Yo creo que algo que hice bien en este proyecto, es que, al momento de encontrarme con un error en mi código, lo que hacía era leer el error y ya con eso intentar identificar lo que estaba ocasionándome ese error. Otra cosa que hice bien en mi opinión es que cuando me encontraba con algo que no sabía hacer o no sabía muy bien cómo hacer, primero lo intentaba resolver por mi cuenta y si al final no lo podía resolver, entonces allí si buscaba en internet como lo podría hacer.
# Por último, me hubiera gustado dejar mi código un poco mas limpio, es decir quitar o simplificar código, ya que creo que hay cosas que podría haber hecho con menos líneas de código. Y también dejarlo un poco mas amigable para la vista.

# %% [markdown]
# ## Codigo

# %%
from random import randrange
import time

datos_reporte = [0,0,0]
base_datos_preguntas = []
"""
base_datos_preguntas = [
    ["Id: 1","Area: matematicas","Pregunta: 1+1","Opcion A: 1","Opcion B: 2","Opcion C: 3","Opcion D: 4","Respuesta: B"],
    ["Id: 2","Area: matematicas","Pregunta: 2+2","Opcion A: 1","Opcion B: 2","Opcion C: 3","Opcion D: 4","Respuesta: D"],
    ["Id: 3","Area: matematicas","Pregunta: 2+1","Opcion A: 1","Opcion B: 2","Opcion C: 3","Opcion D: 4","Respuesta: C"],
    ["Id: 4","Area: matematicas","Pregunta: 3+1","Opcion A: 4","Opcion B: 5","Opcion C: 6","Opcion D: 7","Respuesta: A"],
    ["Id: 5","Area: matematicas","Pregunta: 4+1","Opcion A: 4","Opcion B: 5","Opcion C: 6","Opcion D: 7","Respuesta: B"],
    ["Id: 6","Area: matematicas","Pregunta: 5+1","Opcion A: 4","Opcion B: 5","Opcion C: 6","Opcion D: 7","Respuesta: C"],
    ["Id: 7","Area: ciencias","Pregunta: fuente de energia de la celula","Opcion A: mitocondria","Opcion B: nucleo","Opcion C: nucleolus","Opcion D: ninguna","Respuesta: A"],
    ["Id: 8","Area: ciencias","Pregunta: elige el halogeno ","Opcion A: Pb","Opcion B: F","Opcion C: C","Opcion D: Mg","Respuesta: B"],
    ["Id: 9","Area: lectura","Pregunta: Algo le ocurrió al personaje de la historia la noche anterior. ¿Qué fue lo que le pasó?","Opcion A: El mal tiempo había estropeado la moto. ","Opcion B: El mal tiempo había impedido salir al personaje. ","Opcion C: El personaje había comprado una moto nueva.","Opcion D: El personaje había tenido un accidente de moto","Respuesta: D"],
    ["Id: 10","Area: matematicas","Pregunta: 2 * 2","Opcion A: 4","Opcion B: 5","Opcion C: 6","Opcion D: 7","Respuesta: A"]
]
"""

def main():
    
    while True:
        opcion = menu()

        opcion_existente = opcion == 1 or opcion == 2 or opcion == 3 or opcion == 4 or opcion == 5 or opcion == 6
        nombre_archivo = "preguntas_guardadas.txt" # nombre del archivo de texto

        if opcion_existente != True:
            print("Opcion Incorrecta")
            continue
        elif opcion == 1:
            registrar_preguntas(nombre_archivo)
        elif opcion == 2:
            actualizar_pregunta(nombre_archivo)
        elif opcion == 3:
            estudiar_area(nombre_archivo)
        elif opcion == 4:
            presentar_quiz(nombre_archivo)
        elif opcion == 5:
            reportar_calificaciones()
        elif opcion == 6:
            salir()
            break


def menu():
    # Muestra las opciones y REGRESA la OPCION seleccionada
    print("\n----------------------------------------")
    print("Seleccione una de las siguientes opciones ")
    print("1. Alta de preguntas de prueba PISA")
    print("2. Actualizar preguntas de la prueba PISA")
    print("3. Estudiar preguntas de cierta área")
    print("4. Presentar quiz")
    print("5. Reporte de calificaciones")
    print("6. Salir")

    opcion = int(input("Ingrese el número de la opcion que eligio: "))
    return opcion


def leer_archivo(nombre):
    lista_preguntas = []

    with open(nombre, "r") as archivo:
        contenido = archivo.readlines() # lee todas las líneas del archivo de texto

        for elemento in contenido: # para recorrer cada línea del contenido
            linea = elemento.split(",") # crear una lista con todos los elementos de la línea, cada coma es un elemento
            linea[7] = linea[7][:-1] # borrar la \n del último elemento
            lista_preguntas.append(linea) # agregar la línea (lista) a la lista de preguntas
    
    return lista_preguntas # regresa la lista de preguntas
  

def grabar_archivo(nombre, lista): 

    with open(nombre, "w") as archivo:
        for pregunta in lista: # recorrer pregunta por pregunta la lista de preguntas
            texto = ",".join(pregunta) # crear un texto o string con todos los elementos de la lista, separados por coma
    
            archivo.write(texto + "\n")


def registrar_preguntas(nombre):
    # Añade preguntas a la base de datos
    # INDICES del array de PREGUNTAS
    # 0 ID de la pregunta
    # 1 Area en minuscula
    # 2 Pregunta 
    # 3 OPCION A 
    # 4 OPCION B 
    # 5 OPCION C 
    # 6 OPCION D 
    # 7 Letra de la Respuesta en mayuscula

    # La base_datos_preguntas queda tal que 
        # base_datos_preguntas[numero de pregunta][id = 0 , area = 1, pregunta = 2, opcion a = 3, opcion b = 4, opcion c = 5, opcion d = 6 respuesta = 7]

    base_datos_preguntas = leer_archivo(nombre) # va a leer los datos de las preguntas que hay en el archivo de texto, y los va a almacenar en una lista

    print("\nComplete los siguientes datos para la nueva pregunta\nOpciones para area: lectura, matematicas, ciencias. Favor de no usar tildes")
    id_nuevo = len(base_datos_preguntas) + 1
    pregunta = [
        "Id: " + str(id_nuevo),
        "Area: " + input("Area: ").lower(), 
        "Pregunta: " + input("Pregunta: "), 
        "Opcion A: " + input("Opcion A: "),
        "Opcion B: " + input("Opcion B: "),
        "Opcion C: " + input("Opcion C: "),
        "Opcion D: " + input("Opcion D: "),
        "Respuesta: " + input("Respuesta: ").upper()
    ]

    base_datos_preguntas.append(pregunta) # añadir datos pregunta a la base de datos
    
    print("\nRespuesta registrada correctamente con los siguientes datos:")
    for num in range(len(pregunta)): # imprime los datos de la pregunta recien creada
        print(base_datos_preguntas[id_nuevo -1][num])
    
    grabar_archivo(nombre, base_datos_preguntas) # Llama a la funcion grabar archivo, con parametros (nombre del archivo txt, nombre de la lista)
                                                 # despues de haber cambiado la lista dentro del programa, se manda a actualizar el archivo txt 
                                                 # con la nueva pregunta


def actualizar_pregunta(nombre):
    
    base_datos_preguntas = leer_archivo(nombre) # va a leer los datos de las preguntas que hay en el archivo de texto, y los va a almacenar en una lista

    print("\nSección para actualizar preguntas\nSelecciona una de las siguientes opciones para actualizar: \n")

    for num in range(len(base_datos_preguntas)):
        print(f"{base_datos_preguntas[num][0]} {base_datos_preguntas[num][2]}") # imprime el id y pregunta de todas las preguntas en la base de datos
    
    id_pregunta_actualizar = int(input("\nIngrese el id de la pregunta que desee actualizar: "))

    pregunta_temp = [] # funcionara como la lista pregunta temporal

    if id_pregunta_actualizar <= len(base_datos_preguntas) and id_pregunta_actualizar > 0: # checa que el ID ingresado exista y que no sea 0 o menos
        print("\nDatos pregunta a actualizar: \nSi desea actualizar la pregunta, escriba los nuevos datos, sino solo de enter")
        
        pregunta_temp.append("Id: " + str(id_pregunta_actualizar))

        for num in range(1, len(base_datos_preguntas[id_pregunta_actualizar - 1])): # recorre la lista de la pregunta seleccionada empezando desde 1 (area)
            print(base_datos_preguntas[id_pregunta_actualizar - 1][num]) #imprime la informacion existente

            nuevo_dato_string = base_datos_preguntas[id_pregunta_actualizar - 1][num]
            nuevo_dato_tipo = nuevo_dato_string.split(":") # conseguira el texto id: , area: , pregunta: etc

            dato_temp = input() # recibira el dato a actualizar o el skip

            if(dato_temp != ""): # si SE escribio un nuevo dato se ejecuta
                if nuevo_dato_tipo[0] != "Respuesta": # este if es para el caso de escribir la RESPUESTA CORRECTA
                                                      # porque en el programa se trabaja con que ese valor siempre
                                                      # tiene que ser en letra mayuscula
                    pregunta_temp.append(nuevo_dato_tipo[0] + ": " + str(dato_temp)) # agregara el texto id: , area: + el dato tecleado por el usuario
                else: # Aqui se cambio la letra de la RESPUESTA CORRECTA a Mayuscula
                    pregunta_temp.append(nuevo_dato_tipo[0] + ": " + str(dato_temp).upper()) # agregara el texto id: , area: + el dato tecleado por el usuario

            else: # si NO se escribio nuevo dato se ejecuta
                pregunta_temp.append(base_datos_preguntas[id_pregunta_actualizar - 1][num]) # agregara el dato existente

        print(f"\nLos nuevos datos de la pregunta id {id_pregunta_actualizar} son: ")
        for num in range(1, len(pregunta_temp)): # imprimira los nuevos datos de la pregunta
            print(pregunta_temp[num])

        while True: # ciclo para elegir si actualizar la pregunta 
            seleccion_ingresar = input("Esta seguro de querer actualizar esta pregunta? y/n ").lower()
            seleccion_existente = seleccion_ingresar == "y" or seleccion_ingresar == "n"

            if seleccion_existente == True: # checa si la opcion ingresada es valida

                if seleccion_ingresar == "y":
                    base_datos_preguntas[id_pregunta_actualizar - 1] = pregunta_temp # actualiza la pregunta con respecto a su id en la lista con 
                                                                                     # todas las preguntas

                    grabar_archivo(nombre, base_datos_preguntas)# Llama a la funcion grabar archivo, con parametros (nombre del archivo txt)
                                                                # (nombre de la lista) 
                                                                # despues de haber cambiado la lista dentro del programa, se manda a actualizar el archivo txt con los nuevos valores
                    print("Pregunta actualizada exitosamente")
                    break
                else:
                    print("Los cambios no fueron guardados")
                    break   

            else:
                print("Ingrese una opcion existente")
                continue
        

    else:
        print("\nNo existe ninguna pregunta con ese id")


def estudiar_area(nombre):
    print("\nEstudiar area")

    base_datos_preguntas = leer_archivo(nombre) # va a leer los datos de las preguntas que hay en el archivo de texto, y los va a almacenar en una lista
    while True:

        print("----------------------------------------")
        print("Ingrese el número del area que desee estudiar:")
        print("1. Lectura")
        print("2. Matemáticas")
        print("3. Ciencias")
        
        area_presentar = int(input("Número de área: "))
        num_preguntas_practicar = int(input("Escriba el número de preguntas que quiere estudiar de esta area: "))
        num_lectura = 0
        num_mate = 0
        num_ciencia = 0
        
        area_presentar_existente = area_presentar == 1 or area_presentar == 2 or area_presentar == 3
        
        for num in range(0, len(base_datos_preguntas)): #contar cuantas preguntas tiene cada area
            if base_datos_preguntas[num][1] == "Area: lectura":
                num_lectura += 1
            elif base_datos_preguntas[num][1] == "Area: matematicas":
                num_mate += 1
            elif base_datos_preguntas[num][1] == "Area: ciencias":
                num_ciencia += 1

        # Esta SECCION de IF y ELIF, eligen el AREA de donde agarrar las preguntas
        if area_presentar_existente != True:
            print("\nOpcion invalida")
            continue

        elif area_presentar == 1:
            print("\nArea lectura")

            if num_preguntas_practicar > num_lectura:
                print(f"Lo sentimos pero no tenemos esa cantidad de preguntas para esta area, por lo que se usaran el maximo que tenemos: {num_lectura}")
                correctas = mostrar_preguntas("Area: lectura", num_lectura, base_datos_preguntas)
                
            else:
                correctas = mostrar_preguntas("Area: lectura", num_preguntas_practicar, base_datos_preguntas)

            break

        elif area_presentar == 2:
            print("\nOpcion matematicas")

            if num_preguntas_practicar > num_mate:
                print(f"Lo sentimos pero no tenemos esa cantidad de preguntas para esta area, por lo que se usaran el maximo que tenemos: {num_mate}")
                correctas = mostrar_preguntas("Area: matematicas", num_mate,base_datos_preguntas)
                
            else:
                correctas = mostrar_preguntas("Area: matematicas", num_preguntas_practicar,base_datos_preguntas)

            break

        elif area_presentar == 3:
            print("\nOpcion ciencias")

            if num_preguntas_practicar > num_ciencia:
                print(f"Lo sentimos pero no tenemos esa cantidad de preguntas para esta area, por lo que se usaran el maximo que tenemos: {num_ciencia}")
                correctas = mostrar_preguntas("Area: ciencias", num_ciencia,base_datos_preguntas)
                
            else:
                correctas = mostrar_preguntas("Area: ciencias", num_preguntas_practicar,base_datos_preguntas)

            break


def presentar_quiz(nombre):
    print("\nPresentar quiz\nPara este quiz tendra 20 minutos, despues de eso aunque ingrese la repuesta, esta no se guardara\n")
    
    correctas = 0
    contador_preguntas = 1
    lista_rand_num = []
    timeout = time.time() + 60*1   # hora actual + 20 minutos
    base_datos_preguntas = leer_archivo(nombre) # va a leer los datos de las preguntas que hay en el archivo de texto, y los va a almacenar en una lista

    while True:
    
        if contador_preguntas == 10 + 1:
            break
        elif time.time() > timeout:
            break
        else:
            rand_num = randrange(0, len(base_datos_preguntas)) # genera un numero random ente 0 y la longitud de la base de datos de preguntas

            # este ciclo while sirve para checar que no se repitan preguntas
            while True:
                if rand_num not in lista_rand_num: # si rand_num no esta en la lista de numeros random ya generados se rompe el ciclo
                    break
                                
                else: # si rand_num  esta en la lista de numeros random ya generados se genera otro rand_num y se continua el ciclo
                    rand_num = randrange(0, len(base_datos_preguntas))
                    continue    

            print("Numero " + str(contador_preguntas)) # incrementa el numero de la pregunta
            for num_dato in range(2, len(base_datos_preguntas[rand_num]) - 1): # imprimira los  datos de la pregunta
                print(base_datos_preguntas[rand_num][num_dato])

            opcion_seleccionda = "Respuesta: " + input("Ingrese la letra de la opción de la respuesta: ").upper()

            if (opcion_seleccionda == base_datos_preguntas[rand_num][7]):
                print("\nCorrecto!!\n")

                if time.time() > timeout:
                    print("Esta respuesta no fue guardada, porque se excedio de tiempo")
                else:
                    correctas += 1
            else:
                print("\nIncorrecto!!\n")

                if time.time() > timeout:
                    print("Esta respuesta no fue guardada, porque se excedio de tiempo")
                else:
                    pass
                                    
            contador_preguntas += 1
            lista_rand_num.append(rand_num)

    print("Examen Finalizado \nPreguntas Correctas:", correctas, "de 10")

    # añadir datos para reporte de calificaciones
    datos_reporte_temp = []
    datos_reporte_temp.append(datos_reporte[0] + 1)
    datos_reporte_temp.append(datos_reporte[1] + correctas)
    datos_reporte_temp.append(datos_reporte[2] + (10 - correctas))

    for num in range(0, 3):
        datos_reporte[num] = datos_reporte_temp[num]


def reportar_calificaciones():
    print("\nReportar calificaciones")
    usuarios = datos_reporte[0]
    correctas = datos_reporte[1]
    incorrectas = datos_reporte[2]

    if usuarios >= 1:
        promedio_calif =  int((correctas / (correctas + incorrectas)) * 100)
        print(f'{"Total de usuarios":<30}{usuarios}\n{"Promedio de calificaciones":<30}{promedio_calif}%\n{"Respuestas correctas":<30}{correctas}\n{"Respuestas incorrectas":<30}{incorrectas}')
    else:
        print("No se pueden mostrar datos de calificaciones, porque aun no hay datos")

def salir():
    print("\nSalir\nGracias por usar el programa. Que tenga buen dia")
    

def mostrar_preguntas(area, cant_preguntas, lista_preguntas):
    correctas = 0
    contador_preguntas = 1
    preguntas_area = []
    id_pregunta_temp = 0
    lista_rand_num = []

    # con este loop se crea una lista temporal solo con las preguntas del area seleccionada
    for num in range(0, len(lista_preguntas)):
    # Este loop recorre todas las preguntas
        
        pregunta_temp = []
        if lista_preguntas[num][1] == area:
            # Cuando el loop recorre todas las preguntas ESTE IF, se ejecuta cuando el AREA es la seleccionada

            pregunta_temp.append("id: " + str(id_pregunta_temp)) # le agrega el id empezando de 0
            for num_dato in range(1, len(lista_preguntas[num])): # guarda los valores de la pregunta en una lista temporal
                pregunta_temp.append(lista_preguntas[num][num_dato])
                    
            preguntas_area.append(pregunta_temp) # añade la pregunta temporal(lista) a una lista con varias preguntas de esa area
            id_pregunta_temp += 1
    
    
    for num in range(0, cant_preguntas): # se corre la cantidad de veces que el usuario ingreso
        rand_num = randrange(0, len(preguntas_area)) # genera un numero random ente 0 y la longitud de la lista que contiene preguntas del area seleccionada

        # este ciclo while sirve para checar que no se repitan preguntas
        while True:
            if rand_num not in lista_rand_num: # si rand_num no esta en la lista de numeros random ya generados se rompe el ciclo
                break
                
            else: # si rand_num  esta en la lista de numeros random ya generados se genera otro rand_num y se continua el ciclo
                rand_num = randrange(0, len(preguntas_area))
                continue    

        print("Numero " + str(contador_preguntas)) # incrementa el numero de la pregunta
        for num_dato in range(2, len(preguntas_area[rand_num]) - 1): # imprimira los  datos de la pregunta
            print(preguntas_area[rand_num][num_dato])

        opcion_seleccionda = "Respuesta: " + input("Ingrese la letra de la opción de la respuesta: ").upper()

        if (opcion_seleccionda == preguntas_area[rand_num][7]):
            print("\nCorrecto!!\n")
            correctas += 1
        else:
            print("\nIncorrecto!!\n")
                    
        contador_preguntas += 1
        lista_rand_num.append(rand_num)

    print("Practica Finalizada \nPreguntas Correctas:", correctas, "de", cant_preguntas)
    return correctas
    
main()
# Out:
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 1
#
# Complete los siguientes datos para la nueva pregunta
# Opciones para area: lectura, matematicas, ciencias. Favor de no usar tildes
# Area: matematicas
# Pregunta: 5 * 5
# Opcion A: 15
# Opcion B: 20
# Opcion C: 25
# Opcion D: 30
# Respuesta: a
#
# Respuesta registrada correctamente con los siguientes datos:
# Id: 11
# Area: matematicas
# Pregunta: 5 * 5
# Opcion A: 15
# Opcion B: 20
# Opcion C: 25
# Opcion D: 30
# Respuesta: A
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 2
#
# Sección para actualizar preguntas
# Selecciona una de las siguientes opciones para actualizar:
#
# Id: 1 Pregunta: 1 + 1 + 1
# Id: 2 Pregunta: 2+2
# Id: 3 Pregunta: 2+1
# Id: 4 Pregunta: 3+1
# Id: 5 Pregunta: 4+1
# Id: 6 Pregunta: 5+1
# Id: 7 Pregunta: fuente de energia de la celula
# Id: 8 Pregunta: elige el halogeno
# Id: 9 Pregunta: Algo le ocurrio al personaje de la historia la noche anterior. Que fue lo que le paso?
# Id: 10 Pregunta: 2 * 2
# Id: 11 Pregunta: 5 * 5
#
# Ingrese el id de la pregunta que desee actualizar: 11
#
# Datos pregunta a actualizar:
# Si desea actualizar la pregunta, escriba los nuevos datos, sino solo de enter
# Area: matematicas
#
# Pregunta: 5 * 5
#
# Opcion A: 15
#
# Opcion B: 20
#
# Opcion C: 25
#
# Opcion D: 30
#
# Respuesta: A
# c
#
# Los nuevos datos de la pregunta id 11 son:
# Area: matematicas
# Pregunta: 5 * 5
# Opcion A: 15
# Opcion B: 20
# Opcion C: 25
# Opcion D: 30
# Respuesta: C
# Esta seguro de querer actualizar esta pregunta? y/n i
# Ingrese una opcion existente
# Esta seguro de querer actualizar esta pregunta? y/n y
# Pregunta actualizada exitosamente
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 2
#
# Sección para actualizar preguntas
# Selecciona una de las siguientes opciones para actualizar:
#
# Id: 1 Pregunta: 1 + 1 + 1
# Id: 2 Pregunta: 2+2
# Id: 3 Pregunta: 2+1
# Id: 4 Pregunta: 3+1
# Id: 5 Pregunta: 4+1
# Id: 6 Pregunta: 5+1
# Id: 7 Pregunta: fuente de energia de la celula
# Id: 8 Pregunta: elige el halogeno
# Id: 9 Pregunta: Algo le ocurrio al personaje de la historia la noche anterior. Que fue lo que le paso?
# Id: 10 Pregunta: 2 * 2
# Id: 11 Pregunta: 5 * 5
#
# Ingrese el id de la pregunta que desee actualizar: 0
#
# No existe ninguna pregunta con ese id
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 3
#
# Estudiar area
# ----------------------------------------
# Ingrese el número del area que desee estudiar:
# 1. Lectura
# 2. Matemáticas
# 3. Ciencias
# Número de área: 1
# Escriba el número de preguntas que quiere estudiar de esta area: 2
#
# Area lectura
# Lo sentimos pero no tenemos esa cantidad de preguntas para esta area, por lo que se usaran el maximo que tenemos: 1
# Numero 1
# Pregunta: Algo le ocurrio al personaje de la historia la noche anterior. Que fue lo que le paso?
# Opcion A: El mal tiempo habia estropeado la moto.
# Opcion B: El mal tiempo habia impedido salir al personaje.
# Opcion C: El personaje habia comprado una moto nueva.
# Opcion D: El personaje habia tenido un accidente de moto
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Practica Finalizada
# Preguntas Correctas: 0 de 1
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 3
#
# Estudiar area
# ----------------------------------------
# Ingrese el número del area que desee estudiar:
# 1. Lectura
# 2. Matemáticas
# 3. Ciencias
# Número de área: 2
# Escriba el número de preguntas que quiere estudiar de esta area: 3
#
# Opcion matematicas
# Numero 1
# Pregunta: 2+1
# Opcion A: 1
# Opcion B: 2
# Opcion C: 3
# Opcion D: 4
# Ingrese la letra de la opción de la respuesta: c
#
# Correcto!!
#
# Numero 2
# Pregunta: 5 * 5
# Opcion A: 15
# Opcion B: 20
# Opcion C: 25
# Opcion D: 30
# Ingrese la letra de la opción de la respuesta: c
#
# Correcto!!
#
# Numero 3
# Pregunta: 4+1
# Opcion A: 4
# Opcion B: 5
# Opcion C: 6
# Opcion D: 7
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Practica Finalizada
# Preguntas Correctas: 2 de 3
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 5
#
# Reportar calificaciones
# No se pueden mostrar datos de calificaciones, porque aun no hay datos
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 4
#
# Presentar quiz
# Para este quiz tendra 20 minutos, despues de eso aunque ingrese la repuesta, esta no se guardara
#
# Numero 1
# Pregunta: elige el halogeno
# Opcion A: Pb
# Opcion B: F
# Opcion C: C
# Opcion D: Mg
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 2
# Pregunta: 2 * 2
# Opcion A: 4
# Opcion B: 5
# Opcion C: 6
# Opcion D: 7
# Ingrese la letra de la opción de la respuesta: a
#
# Correcto!!
#
# Numero 3
# Pregunta: 2+2
# Opcion A: 1
# Opcion B: 2
# Opcion C: 3
# Opcion D: 4
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 4
# Pregunta: 2+1
# Opcion A: 1
# Opcion B: 2
# Opcion C: 3
# Opcion D: 4
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 5
# Pregunta: 3+1
# Opcion A: 4
# Opcion B: 5
# Opcion C: 6
# Opcion D: 7
# Ingrese la letra de la opción de la respuesta: a
#
# Correcto!!
#
# Numero 6
# Pregunta: 4+1
# Opcion A: 4
# Opcion B: 5
# Opcion C: 6
# Opcion D: 7
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 7
# Pregunta: 5 * 5
# Opcion A: 15
# Opcion B: 20
# Opcion C: 25
# Opcion D: 30
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 8
# Pregunta: 1 + 1 + 1
# Opcion A: 3
# Opcion B: 4
# Opcion C: 5
# Opcion D: 6
# Ingrese la letra de la opción de la respuesta: a
#
# Correcto!!
#
# Numero 9
# Pregunta: 5+1
# Opcion A: 4
# Opcion B: 5
# Opcion C: 6
# Opcion D: 7
# Ingrese la letra de la opción de la respuesta: a
#
# Incorrecto!!
#
# Numero 10
# Pregunta: fuente de energia de la celula
# Opcion A: mitocondria
# Opcion B: nucleo
# Opcion C: nucleolus
# Opcion D: ninguna
# Ingrese la letra de la opción de la respuesta: a
#
# Correcto!!
#
# Examen Finalizado
# Preguntas Correctas: 4 de 10
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 5
#
# Reportar calificaciones
# Total de usuarios             1
# Promedio de calificaciones    40%
# Respuestas correctas          4
# Respuestas incorrectas        6
#
# ----------------------------------------
# Seleccione una de las siguientes opciones
# 1. Alta de preguntas de prueba PISA
# 2. Actualizar preguntas de la prueba PISA
# 3. Estudiar preguntas de cierta área
# 4. Presentar quiz
# 5. Reporte de calificaciones
# 6. Salir
# Ingrese el número de la opcion que eligio: 6
#
# Salir
# Gracias por usar el programa. Que tenga buen dia
